# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a TSV of publications with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `publications.py`. Run either from the `markdown_generator` folder after replacing `publications.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases of citations, rather than Stuart's non-standard TSV format and citation style.

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: pub_date, title, venue, excerpt, citation, site_url, and paper_url, with a header at the top.
#
# - `excerpt` and `paper_url` can be blank, but the others must have values.
# - `pub_date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper. The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/publications/YYYY-MM-DD-[url_slug]`
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
# !cat publications.tsv
# Out:
# ID	pub_date	title	venue	excerpt	citation	url_slug	paper_url	slides_url	category
# 1M	10/23/2025	Optimization of RIS-assisted Cell-free Massive MIMO Systems with Heterogeneous Graph Neural Networks under Imperfect Channel Estimation	IEEE Transactions on Vehicular Technology	"This study investigates a cell-free massive MIMO system integrated with a reconfigurable intelligent surface (RIS), focusing on performance under imperfect channel estimation and pilot contamination. Proposes a heterogeneous graph neural network (HetGNN) architecture to optimize the RIS-assisted CFMM system for maximizing performance."	"Nguyen, Q.-S., Dang, X.-T., & Shin, O.-S. (2025). ""Optimization of RIS-assisted Cell-free Massive MIMO Systems with Heterogeneous Graph Neural Networks under Imperfect Channel Estimation."" <i>IEEE Transactions on Vehicular Technology</i>."	optimization-ris-cfmm-hetgnn-imperfect-channel	https://ieeexplore.ieee.org/document/11216092		manuscripts
# 2M	7/18/2025	Optimization of Energy Efficiency for Federated Learning over IRS-assisted Cell-free Massive MIMO Networks	IEEE Transactions on Wireless Communications	This paper explores the optimization of energy efficiency for federated learning in an intelligent reflecting surface (IRS)-assisted cell-free massive MIMO network.	"Dang, X.-T., Nguyen, H. V., & Shin, O.-S. (2025). ""Optimization of Energy Efficiency for Federated Learning over IRS-assisted Cell-free Massive MIMO Networks."" <i>IEEE Transactions on Wireless Communications</i>."	optimization-energy-efficiency-federated-learning-irs-mimo	https://doi.org/10.1109/TWC.2025.3588353		manuscripts
# 3M	8/15/2025	Optimizing Energy Efficiency for Federated Learning in Rotary-Wing UAV Air-to-Ground Communications	IEEE Transactions on Green Communications and Networking	Focuses on enhancing the energy efficiency of federated learning systems utilizing rotary-wing unmanned aerial vehicles (UAVs) for air-to-ground communication.	"Dang, X.-T., Nguyen, Q.-S., & Shin, O.-S. (2025). ""Optimizing Energy Efficiency for Federated Learning in Rotary-Wing UAV Air-to-Ground Communications."" <i>IEEE Transactions on Green Communications and Networking</i>."	optimizing-energy-efficiency-federated-learning-uav-communications	https://doi.org/10.1109/TGCN.2025.3599309		manuscripts
# 4M	8/1/2025	A DDPG-LSTM Framework for Optimizing UAV-Enabled Integrated Sensing and Communication	Drones	Presents a framework combining Deep Deterministic Policy Gradient (DDPG) and Long Short-Term Memory (LSTM) networks to optimize Integrated Sensing and Communication (ISC) systems enabled by UAVs.	"Dang, X.-T., Eom, J.-S., Vu, B.-M., & Shin, O.-S. (2025). ""A DDPG-LSTM Framework for Optimizing UAV-Enabled Integrated Sensing and Communication."" <i>Drones</i>, 9(8), 548."	ddpg-lstm-framework-optimizing-uav-sensing-communication	https://doi.org/10.3390/drones9080548		manuscripts
# 5M	4/22/2025	Combining the Viterbi Algorithm and Graph Neural Networks for Efficient MIMO Detection	Electronics	Investigates a novel method for efficient Multiple-Input Multiple-Output (MIMO) detection by integrating the Viterbi algorithm with Graph Neural Networks (GNNs).	"Nguyen, T. A., Dang, X.-T., Shin, O.-S., & Lee, J. (2025). ""Combining the Viterbi Algorithm and Graph Neural Networks for Efficient MIMO Detection."" <i>Electronics</i>, 14(9), 1698."	viterbi-graph-neural-networks-mimo-detection	https://doi.org/10.3390/electronics14091698		manuscripts
# 6M	6/27/2024	Physical Layer Security for IRS-UAV-Assisted Cell-Free Massive MIMO Systems	IEEE Access	Analyzes and enhances physical layer security in cell-free massive MIMO systems assisted by both intelligent reflecting surfaces (IRS) and unmanned aerial vehicles (UAVs).	"Dang, X.-T., Nguyen, H. V., & Shin, O.-S. (2024). ""Physical Layer Security for IRS-UAV-Assisted Cell-Free Massive MIMO Systems."" <i>IEEE Access</i>."	physical-layer-security-irs-uav-massive-mimo	https://doi.org/10.1109/ACCESS.2024.3419888		manuscripts
# 7M	12/23/2024	A Survey on Energy-Efficient Design for Federated Learning over Wireless Networks	Energies	A comprehensive review detailing the current state-of-the-art and challenges in designing energy-efficient federated learning protocols for wireless communication networks.	"Dang, X.-T., Vu, B.-M., Nguyen, Q.-S., Tran, T.-T.-M., Eom, J.-S., & Shin, O.-S. (2024). ""A Survey on Energy-Efficient Design for Federated Learning over Wireless Networks."" <i>Energies</i>, 17(24), 6485."	survey-energy-efficient-federated-learning-wireless	https://doi.org/10.3390/en17246485		manuscripts
# 8M	5/8/2024	Optimization of Energy Efficiency for Federated Learning over Unmanned Aerial Vehicle Communication Networks	Electronics	Focuses on optimizing the energy efficiency of federated learning implementations in communication networks supported by Unmanned Aerial Vehicles (UAVs).	"Dang, X.-T., & Shin, O.-S. (2024). ""Optimization of Energy Efficiency for Federated Learning over Unmanned Aerial Vehicle Communication Networks."" <i>Electronics</i>, 13(10), 1827."	optimization-energy-efficiency-federated-learning-uav-networks	https://doi.org/10.3390/electronics13101827		manuscripts
# 9M	8/30/2023	Optimization of IRS-NOMA-Assisted Cell-Free Massive MIMO Systems Using Deep Reinforcement Learning	IEEE Access	Applies Deep Reinforcement Learning (DRL) to optimize the performance of intelligent reflecting surface (IRS) and NOMA-assisted cell-free massive MIMO systems.	"Dang, X.-T., Nguyen, H. V., & Shin, O.-S. (2023). ""Optimization of IRS-NOMA-Assisted Cell-Free Massive MIMO Systems Using Deep Reinforcement Learning."" <i>IEEE Access</i>."	optimization-irs-noma-mimo-deep-rl	https://doi.org/10.1109/access.2023.3310283		manuscripts
# 10M	12/1/2022	Optimal User Pairing Approach for NOMA-Based Cell-Free Massive MIMO Systems	IEEE Transactions on Vehicular Technology	Proposes an optimal user pairing approach for Non-Orthogonal Multiple Access (NOMA) integration into Cell-Free Massive MIMO systems to maximize sum spectral efficiency.	"Dang, X.-T., Le, M. T. P., Nguyen, H. V., Chatzinotas, S., & Shin, O.-S. (2023). ""Optimal User Pairing Approach for NOMA-Based Cell-Free Massive MIMO Systems."" <i>IEEE Transactions on Vehicular Technology</i>, 72(4), 4751-4765."	optimal-user-pairing-noma-cell-free-massive-mimo	https://doi.org/10.1109/TVT.2022.3225835		manuscripts
#
# 1C	1/13/2021	A genetic algorithm based pilot assignment strategy for cell-free massive MIMO system	2020 IEEE Eighth International Conference on Communications and Electronics…	Investigates a genetic algorithm for pilot assignment to optimize cell-free massive MIMO systems.	"Dang, X.-T. et al. (2021). ""A genetic algorithm based pilot assignment strategy..."" 2020 IEEE Eighth ICCE."	genetic-algorithm-pilot-assignment-mimo	N/A	N/A	conferences
# 2C	7/29/2022	Optimal User Pairing for NOMA-assisted Cell-free Massive MIMO System	2022 IEEE Ninth International Conference on Communications and Electronics…	Proposes an optimal user pairing scheme for NOMA integration in cell-free massive MIMO.	"Dang, X.-T. et al. (2022). ""Optimal User Pairing for NOMA-assisted CFMM."" 2022 IEEE Ninth ICCE."	optimal-user-pairing-noma-cfmm	N/A	N/A	conferences
# 3C	8/1/2023	Optimization of Physical Layer Security in IRSs-assisted Cell-Free Massive MIMO Systems	"2023 VTS Asia Pacific Wireless Communications Symposium (APWCS), Tainan city…"	Focuses on optimizing physical layer security in Intelligent Reflecting Surface (IRS) assisted cell-free massive MIMO.	"Dang, X.-T., Shin, O.-S. (2023). ""Optimization of Physical Layer Security..."" 2023 VTS APWCS."	optimization-physical-layer-security-irs-mimo	N/A	N/A	conferences

# %% [markdown]
# ## Import pandas
#
# We are using the very handy pandas library for dataframes.

# %%
import pandas as pd

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
publications = pd.read_csv("publications.tsv", sep="\t", header=0)
publications
# Out:
#      ID    pub_date                                              title  \
# 0    1M  10/23/2025  Optimization of RIS-assisted Cell-free Massive...
# 1    2M   7/18/2025  Optimization of Energy Efficiency for Federate...
# 2    3M   8/15/2025  Optimizing Energy Efficiency for Federated Lea...
# 3    4M    8/1/2025  A DDPG-LSTM Framework for Optimizing UAV-Enabl...
# 4    5M   4/22/2025  Combining the Viterbi Algorithm and Graph Neur...
# 5    6M   6/27/2024  Physical Layer Security for IRS-UAV-Assisted C...
# 6    7M  12/23/2024  A Survey on Energy-Efficient Design for Federa...
# 7    8M    5/8/2024  Optimization of Energy Efficiency for Federate...
# 8    9M   8/30/2023  Optimization of IRS-NOMA-Assisted Cell-Free Ma...
# 9   10M   12/1/2022  Optimal User Pairing Approach for NOMA-Based C...
# 10  NaN         NaN                                                NaN
# 11   1C   1/13/2021  A genetic algorithm based pilot assignment str...
# 12   2C   7/29/2022  Optimal User Pairing for NOMA-assisted Cell-fr...
# 13   3C    8/1/2023  Optimization of Physical Layer Security in IRS...
#
#                                                 venue  \
# 0           IEEE Transactions on Vehicular Technology
# 1        IEEE Transactions on Wireless Communications
# 2   IEEE Transactions on Green Communications and ...
# 3                                              Drones
# 4                                         Electronics
# 5                                         IEEE Access
# 6                                            Energies
# 7                                         Electronics
# 8                                         IEEE Access
# 9           IEEE Transactions on Vehicular Technology
# 10                                                NaN
# 11  2020 IEEE Eighth International Conference on C...
# 12  2022 IEEE Ninth International Conference on Co...
# 13  2023 VTS Asia Pacific Wireless Communications ...
#
#                                               excerpt  \
# 0   This study investigates a cell-free massive MI...
# 1   This paper explores the optimization of energy...
# 2   Focuses on enhancing the energy efficiency of ...
# 3   Presents a framework combining Deep Determinis...
# 4   Investigates a novel method for efficient Mult...
# 5   Analyzes and enhances physical layer security ...
# 6   A comprehensive review detailing the current s...
# 7   Focuses on optimizing the energy efficiency of...
# 8   Applies Deep Reinforcement Learning (DRL) to o...
# 9   Proposes an optimal user pairing approach for ...
# 10                                                NaN
# 11  Investigates a genetic algorithm for pilot ass...
# 12  Proposes an optimal user pairing scheme for NO...
# 13  Focuses on optimizing physical layer security ...
#
#                                              citation  \
# 0   Nguyen, Q.-S., Dang, X.-T., & Shin, O.-S. (202...
# 1   Dang, X.-T., Nguyen, H. V., & Shin, O.-S. (202...
# 2   Dang, X.-T., Nguyen, Q.-S., & Shin, O.-S. (202...
# 3   Dang, X.-T., Eom, J.-S., Vu, B.-M., & Shin, O....
# 4   Nguyen, T. A., Dang, X.-T., Shin, O.-S., & Lee...
# 5   Dang, X.-T., Nguyen, H. V., & Shin, O.-S. (202...
# 6   Dang, X.-T., Vu, B.-M., Nguyen, Q.-S., Tran, T...
# 7   Dang, X.-T., & Shin, O.-S. (2024). "Optimizati...
# 8   Dang, X.-T., Nguyen, H. V., & Shin, O.-S. (202...
# 9   Dang, X.-T., Le, M. T. P., Nguyen, H. V., Chat...
# 10                                                NaN
# 11  Dang, X.-T. et al. (2021). "A genetic algorith...
# 12  Dang, X.-T. et al. (2022). "Optimal User Pairi...
# 13  Dang, X.-T., Shin, O.-S. (2023). "Optimization...
#
#                                              url_slug  \
# 0      optimization-ris-cfmm-hetgnn-imperfect-channel
# 1   optimization-energy-efficiency-federated-learn...
# 2   optimizing-energy-efficiency-federated-learnin...
# 3   ddpg-lstm-framework-optimizing-uav-sensing-com...
# 4        viterbi-graph-neural-networks-mimo-detection
# 5        physical-layer-security-irs-uav-massive-mimo
# 6   survey-energy-efficient-federated-learning-wir...
# 7   optimization-energy-efficiency-federated-learn...
# 8                  optimization-irs-noma-mimo-deep-rl
# 9    optimal-user-pairing-noma-cell-free-massive-mimo
# 10                                                NaN
# 11            genetic-algorithm-pilot-assignment-mimo
# 12                     optimal-user-pairing-noma-cfmm
# 13      optimization-physical-layer-security-irs-mimo
#
#                                         paper_url  slides_url     category
# 0   https://ieeexplore.ieee.org/document/11216092         NaN  manuscripts
# 1        https://doi.org/10.1109/TWC.2025.3588353         NaN  manuscripts
# 2       https://doi.org/10.1109/TGCN.2025.3599309         NaN  manuscripts
# 3           https://doi.org/10.3390/drones9080548         NaN  manuscripts
# 4     https://doi.org/10.3390/electronics14091698         NaN  manuscripts
# 5     https://doi.org/10.1109/ACCESS.2024.3419888         NaN  manuscripts
# 6              https://doi.org/10.3390/en17246485         NaN  manuscripts
# 7     https://doi.org/10.3390/electronics13101827         NaN  manuscripts
# 8     https://doi.org/10.1109/access.2023.3310283         NaN  manuscripts
# 9        https://doi.org/10.1109/TVT.2022.3225835         NaN  manuscripts
# 10                                            NaN         NaN          NaN
# 11                                            NaN         NaN  conferences
# 12                                            NaN         NaN  conferences
# 13                                            NaN         NaN  conferences

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
# coding: utf-8

# # Publications markdown generator for academicpages
# 
# Takes a TSV of publications with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook, with the core python code in publications.py. Run either from the `markdown_generator` folder after replacing `publications.tsv` with one that fits your format.
# 
# TODO: Make this work with BibTex and other databases of citations, rather than Stuart's non-standard TSV format and citation style.
# 

# ## Data format
# 
# The TSV needs to have the following columns: pub_date, title, venue, excerpt, citation, url_slug, paper_url, slides_url with a header at the top. 
# 
# - `excerpt` and `paper_url` can be blank, but the others must have values. 
# - `pub_date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper. The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/publications/YYYY-MM-DD-[url_slug]`


# ## Import pandas
# 
# We are using the very handy pandas library for dataframes.

# In[2]:

import pandas as pd
import os

# HTML escape function
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
}

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)


# ## Import TSV
# 
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
# 
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# In[3]:

publications = pd.read_csv("publications.tsv", sep="\t", header=0)
publications


# ## Creating the markdown files
# 
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# In[5]:

for row, item in publications.iterrows():
    
    md_filename = str(item.ID) + ".md"
    html_filename = str(item.ID) + "-" + item.url_slug
    year = item.pub_date[:4]
    
    ## YAML variables
    
    md = "---\ntitle: \""   + item.title + '"\n'

    md =  "ID: " + str(item.ID) + "\n"
    
    md += """collection: publications"""
    
    md += """\npermalink: /publication/""" + html_filename
    
    # Add category
    if 'category' in item and len(str(item.category)) > 3:
        md += "\ncategory: '" + str(item.category) + "'"
    
    if len(str(item.excerpt)) > 5:
        md += "\nexcerpt: '" + html_escape(item.excerpt) + "'"
    
    md += "\ndate: " + str(item.pub_date) 
    
    md += "\nvenue: '" + html_escape(item.venue) + "'"
    
    if len(str(item.paper_url)) > 5 and str(item.paper_url) != 'nan':
        md += "\npaperurl: '" + item.paper_url + "'"
    
    if len(str(item.slides_url)) > 5 and str(item.slides_url) != 'nan' and not str(item.slides_url).startswith('#'):
        md += "\nslidesurl: '" + item.slides_url + "'"
    
    md += "\ncitation: '" + html_escape(item.citation) + "'"
    
    md += "\n---"
    
    ## Markdown description for individual page
    
    if len(str(item.excerpt)) > 5:
        md += "\n\n" + html_escape(item.excerpt) + "\n"
    
    if len(str(item.paper_url)) > 5 and str(item.paper_url) != 'nan':
        md += "\n[Download paper here](" + item.paper_url + ")\n" 
    
    if len(str(item.slides_url)) > 5 and str(item.slides_url) != 'nan' and not str(item.slides_url).startswith('#'):
        md += "\n[Download slides here](" + item.slides_url + ")\n"
        
    md += "\nRecommended citation: " + item.citation
    
    md_filename = os.path.basename(md_filename)
       
    with open("../_publications/" + md_filename, 'w') as f:
        f.write(md)

print("Publications markdown files generated successfully!")
# Out:
# Publications markdown files generated successfully!

# %% [markdown]
# These files are in the publications directory, one directory below where we're working from.
